# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv('D:/Kaggle/Housing Problem/train.csv')

# %%
""""pd.reset_option('display.height', 1000)
pd.reset_option('display.max_rows', 500)
pd.reset_option('display.max_columns', 500)
pd.reset_option('display.width', 1000)""""

# %%
pd.options.display.max_columns = None
pd.set_option('display.max_colwidth', -1)
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1   60          RL       65.0         8450     Pave   NaN   Reg
# 1  2   20          RL       80.0         9600     Pave   NaN   Reg
# 2  3   60          RL       68.0         11250    Pave   NaN   IR1
# 3  4   70          RL       60.0         9550     Pave   NaN   IR1
# 4  5   60          RL       84.0         14260    Pave   NaN   IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0  Lvl         AllPub    Inside    Gtl       CollgCr      Norm
# 1  Lvl         AllPub    FR2       Gtl       Veenker      Feedr
# 2  Lvl         AllPub    Inside    Gtl       CollgCr      Norm
# 3  Lvl         AllPub    Corner    Gtl       Crawfor      Norm
# 4  Lvl         AllPub    FR2       Gtl       NoRidge      Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0  Norm       1Fam     2Story     7            5            2003
# ...

# %%
train.describe(include= 'all')
# Out:
#                  Id   MSSubClass MSZoning  LotFrontage        LotArea Street  \
# count   1460.000000  1460.000000  1460     1201.000000  1460.000000    1460
# unique NaN          NaN           5       NaN          NaN             2
# top    NaN          NaN           RL      NaN          NaN             Pave
# freq   NaN          NaN           1151    NaN          NaN             1454
# mean    730.500000   56.897260    NaN      70.049958    10516.828082   NaN
# std     421.610009   42.300571    NaN      24.284752    9981.264932    NaN
# min     1.000000     20.000000    NaN      21.000000    1300.000000    NaN
# 25%     365.750000   20.000000    NaN      59.000000    7553.500000    NaN
# 50%     730.500000   50.000000    NaN      69.000000    9478.500000    NaN
# 75%     1095.250000  70.000000    NaN      80.000000    11601.500000   NaN
# max     1460.000000  190.000000   NaN      313.000000   215245.000000  NaN
#
# ...

# %%
train_count = train.count()
print train_count
# Out:
# Id               1460
# MSSubClass       1460
# MSZoning         1460
# LotFrontage      1201
# LotArea          1460
# Street           1460
# Alley            91
# LotShape         1460
# LandContour      1460
# Utilities        1460
# LotConfig        1460
# LandSlope        1460
# Neighborhood     1460
# Condition1       1460
# Condition2       1460
# BldgType         1460
# HouseStyle       1460
# OverallQual      1460
# OverallCond      1460
# YearBuilt        1460
# YearRemodAdd     1460
# RoofStyle        1460
# RoofMatl         1460
# Exterior1st      1460
# Exterior2nd      1460
# MasVnrType       1452
# MasVnrArea       1452
# ExterQual        1460
# ExterCond        1460
# Foundation       1460
#                  ...
# BedroomAbvGr     1460
# KitchenAbvGr     1460
# KitchenQual      1460
# TotRmsAbvGrd     1460
# Functional       1460
# Fireplaces       1460
# FireplaceQu      770
# GarageType       1379
# GarageYrBlt      1379
# GarageFinish     1379
# ...

# %%
col_names = list(train)

# %%
print col_names
# Out:
# ['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQ
# ...

# %%
h = train.isnull().sum()
nadic = {}
naper = {}
colna = 0.0
for col in list(train):
    colna = train[col].isnull().sum()
    #print type(colna)
    if colna > 0:
        nadic[col] = float(colna)
        naper[col] = (float(colna)/len(train))*100
print nadic
print naper
print nadic
# Out:
# {'MasVnrArea': 8.0, 'PoolQC': 1453.0, 'MasVnrType': 8.0, 'GarageType': 81.0, 'BsmtCond': 37.0, 'LotFrontage': 259.0, 'MiscFeature': 1406.0, 'GarageFinish': 81.0, 'GarageYrBlt': 81.0, 'Alley': 1369.0, 'GarageQual': 81.0, 'Electrical': 1.0, 'Fence': 1179.0, 'BsmtFinType2': 38.0, 'BsmtQual': 37.0, 'FireplaceQu': 690.0, 'BsmtExposure': 38.0, 'BsmtFinType1': 37.0, 'GarageCond': 81.0}
# ...

# %%
def find_missing_values(data):
    nadic = {}
    colna = 0.0
    nadicper
    for col in list(data):
        colna = data[col].isnull().sum()
        if colna > 0 or (colna/len(data)) > 0.4:
            nadic[col] = colna
        
    return nadic

# %%
all_data = train
all_data_na = (all_data.isnull().sum() / len(all_data)) * 100
#print all_data_na
all_data_na = all_data_na.drop(all_data_na[all_data_na == 0].index).sort_values(ascending=False)[:30]
missing_data = pd.DataFrame({'Missing Ratio' :all_data_na})
print missing_data.head(10)
top_missing = list(missing_data.head(30).index[0:5])
print top_missing
# Out:
#               Missing Ratio
# PoolQC        99.520548
# MiscFeature   96.301370
# Alley         93.767123
# Fence         80.753425
# FireplaceQu   47.260274
# LotFrontage   17.739726
# GarageYrBlt   5.547945
# GarageType    5.547945
# GarageFinish  5.547945
# GarageQual    5.547945
# ['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'FireplaceQu']

# %%
train.loc[:,top_missing].head(10)
# Out:
#   PoolQC MiscFeature Alley  Fence FireplaceQu
# 0  NaN    NaN         NaN   NaN    NaN
# 1  NaN    NaN         NaN   NaN    TA
# 2  NaN    NaN         NaN   NaN    TA
# 3  NaN    NaN         NaN   NaN    Gd
# 4  NaN    NaN         NaN   NaN    TA
# 5  NaN    Shed        NaN   MnPrv  NaN
# 6  NaN    NaN         NaN   NaN    Gd
# 7  NaN    Shed        NaN   NaN    TA
# 8  NaN    NaN         NaN   NaN    TA
# 9  NaN    NaN         NaN   NaN    TA

# %%
list(train['FireplaceQu'].value_counts().index)
# Out:
# Gd    380
# TA    313
# Fa    33
# Ex    24
# Po    20
# Name: FireplaceQu, dtype: int64

# %%
train['FireplaceQu'] = train['FireplaceQu'].fillna(0)
rep_fire = {'FireplaceQu':{'Ex':5,'Gd':4,'TA':3,'Fa':2,'Po':1}}
train.replace(rep_fire,inplace=True)
train['FireplaceQu'].value_counts()
# Out:
# 0    690
# 4    380
# 3    313
# 2    33
# 5    24
# 1    20
# Name: FireplaceQu, dtype: int64

# %%
std_filter = train.std()
std_filter = std_filter[std_filter > 1]
print std_filter
# Out:
# Id               421.610009
# MSSubClass       42.300571
# LotFrontage      24.284752
# LotArea          9981.264932
# OverallQual      1.382997
# OverallCond      1.112799
# YearBuilt        30.202904
# YearRemodAdd     20.645407
# MasVnrArea       181.066207
# BsmtFinSF1       456.098091
# BsmtFinSF2       161.319273
# BsmtUnfSF        441.866955
# TotalBsmtSF      438.705324
# 1stFlrSF         386.587738
# 2ndFlrSF         436.528436
# LowQualFinSF     48.623081
# GrLivArea        525.480383
# TotRmsAbvGrd     1.625393
# GarageYrBlt      24.689725
# GarageArea       213.804841
# WoodDeckSF       125.338794
# OpenPorchSF      66.256028
# EnclosedPorch    61.119149
# 3SsnPorch        29.317331
# ScreenPorch      55.757415
# PoolArea         40.177307
# MiscVal          496.123024
# MoSold           2.703626
# YrSold           1.328095
# SalePrice        79442.502883
# dtype: float64

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# ...

# %%
#noticed all cat variable are read as object
cat_variable = list(train.select_dtypes(['object']).columns.values)
num_variable = list(train.select_dtypes(['int64','float64']).columns.values)
print len(cat_variable) + len(num_variable)
# Out:
# 81

# %%
print cat_variable
# Out:
# ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']

# %%
 import matplotlib.pyplot as plt
# %matplotlib inline
train.boxplot('SalePrice','FireplaceQu')

# %%
from ggplot import *

# %%
train['LotShape'].value_counts()
# Out:
# Reg    925
# IR1    484
# IR2    41
# IR3    10
# Name: LotShape, dtype: int64

# %%
import seaborn as sns

# %%
val_count = train['FireplaceQu'].value_counts()
sns.set(style="darkgrid")
sns.barplot(val_count.index,val_count.values,alpha=0.95)
plt.show()

# %%
sns.barplot(train['OverallQual'],train['SalePrice'])

# %%
sns.scatterplot(train['GrLivArea'],train['SalePrice'])

# %%
sns.scatterplot(train[train['GrLivArea'] < 3000]['GrLivArea'],train[train['SalePrice'] < 500000]['SalePrice'])

# %%
sns.scatterplot(train['LotArea'],train['SalePrice'])

# %%
train.plot.scatter(x='GrLivArea',y='SalePrice')

# %%
plt.hist(train.SalePrice)
plt.show()

# %%
train['Logsaleprice'] = np.log(train.SalePrice)

# %%
plt.hist(train.Logsaleprice)
# Out:
# (array([   5.,   12.,   54.,  184.,  470.,  400.,  220.,   90.,   19.,    6.]),
#  array([ 10.46024211,  10.7676652 ,  11.07508829,  11.38251138,
#          11.68993448,  11.99735757,  12.30478066,  12.61220375,
#          12.91962684,  13.22704994,  13.53447303]),
#  <a list of 10 Patch objects>)

# %%
strain = train[(train['GrLivArea'] < 3000) & (train['SalePrice'] < 500000)]

# %%
strain.shape
# Out:
# (1437, 81)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from ggplot import *
ggplot(aes(x='SalePrice'), data=train) + geom_histogram()
ggplot(aes(x='GrLivArea',y='SalePrice'), data=strain) + geom_jitter()
# Out:
# <ggplot: (13786197)>

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\sarra\Anaconda2\lib\site-packages\IPython\core\formatters.pyc in __call__(self, obj)
#     697                 type_pprinters=self.type_printers,
#     698                 deferred_pprinters=self.deferred_printers)
# --> 699             printer.pretty(obj)
#     700             printer.flush()
#     701             return stream.getvalue()
#
# C:\Users\sarra\Anaconda2\lib\site-packages\IPython\lib\pretty.pyc in pretty(self, obj)
#     381                             if callable(meth):
#     382                                 return meth(obj, self, cycle)
# --> 383             return _default_pprint(obj, self, cycle)
#     384         finally:
#     385             self.end_group()
#
# C:\Users\sarra\Anaconda2\lib\site-packages\IPython\lib\pretty.pyc in _default_pprint(obj, p, cycle)
# ...
